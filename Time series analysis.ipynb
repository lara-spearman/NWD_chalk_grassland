# %%
import fiona 
import geopandas as gpd

# Get all the layers from the .gdb file 
layers = fiona.listlayers(gdb_file)

for layer in layers:
    gdf = gpd.read_file(gdb_file,layer=layer)
    # Do stuff with the gdf

# %%
import os
import geopandas as gpd
import pandas as pd

# %%
path = "O:/NWD_NationalLandscape/Chalk Grassland Strategy Review/GIS/NWD_MPR_CGS/NWD_MPR_CGS.gdb"

# %%
CEH_cat_lookup = pd.read_csv("G:\CEH\docs\CEH_LCClass.csv")

# %%
CEH_list = ["LCM2007_CEH_NWD","LCM2015_CEH_NWD","LCM2017_CEH_NWD","LCM2018_CEH_NWD","LCM2019_CEH_NWD","LCM2020_CEH_NWD","LCM2021_CEH_NWD","LCM2022_CEH_NWD"	,"LCM2023_CEH_NWD"]

# %%
gpd.list_layers(path)
# Out:
#                                                  name    geometry_type
# 0                   Sites_of_Special_Scient_Wiltshire     MultiPolygon
# 1                   SoilParentMateriall_V1__Wiltshire     MultiPolygon
# 2                   Agricultural_Land_Class_Wiltshire     MultiPolygon
# 3                       BGS_625k_Geology_Bedroc_Wilts     MultiPolygon
# 4                               Conservation_Ar_Wilts     MultiPolygon
# 5                                 Country_Parks_Wilts     MultiPolygon
# 6                       Countryside_Stewardship_Wilts     MultiPolygon
# 7                               Doorstep_Greens_Wilts     MultiPolygon
# 8                     Environmental_Stewardship_Wilts     MultiPolygon
# 9    EWCO_Biodiversity_Priority_habitat_network_Wilts     MultiPolygon
# 10  EWCO_Nature_Recovery_priority_habitat_network_...     MultiPolygon
# 11              Environmentally_sensitive_areas_Wilts     MultiPolygon
# ...

# %%
file_info = {'LCM2007_CEH_NWD':'BH', 
             'LCM2015_CEH_NWD':'bhab',
             
            'LCM2023_CEH_NWD':'_mode'}

# %%
gdf4 = gpd.read_file(path,layer='LCM2017_CEH_NWD',rows=10)

# %%
gdf4
# Out:
# Empty GeoDataFrame
# Columns: [gid, _hist, _mode, _purity, _conf, _stdev, _n, GEOMETRY_Length, GEOMETRY_Area, geometry]
# Index: []
